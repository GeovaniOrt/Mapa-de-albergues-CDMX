# %% [markdown]
# <a href="https://colab.research.google.com/github/GeovaniOrt/Mapa-de-albergues-CDMX/blob/main/Mapa_Albergues_Didactico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  data = pd.read_csv('/content/datos de albergues.csv', encoding='latin-1')
except FileNotFoundError:
  print("Error: El archivo albergues_cdmx.csv no se encontró.")
  exit()
# 2. Crear el mapa centrado en la CDMX (puedes ajustar las coordenadas y el zoom)
mapa_cdmx = folium.Map(location=[19.4326, -99.1332], zoom_start=11)

# 3. Iterar a través de cada fila del DataFrame para agregar los marcadores
for index, row in data.iterrows():
    latitud = row['latitud']
    longitud = row['longitud']
    nombre = row.get('nombrerefugio')  # Obtener el nombre si existe, sino usar 'Albergue'
    capacidad = row['capacidad']
    alcaldia = row['alcaldia']

    # Crear el texto emergente (popup) para cada marcador
    popup_text = f"Nombre:{nombre} Capacidad: {capacidad} personas  Alcaldia: {alcaldia}"
    popup = folium.Popup(popup_text, parse_html=True)

    #Colores
        # Determinar color basado en la capacidad
    if capacidad <= 100:
        circle_color = 'blue'
    elif capacidad <= 300:
        circle_color = 'green'
    elif capacidad <= 600:
        circle_color = 'yellow'
    elif 600 < capacidad <= 800:  # Condición corregida
        circle_color = 'orange'
    else:
        circle_color = 'red'

    # Crear el marcador y añadirlo al mapa
    folium.CircleMarker(
        location=[latitud, longitud],
        radius=capacidad / 20,  # Ajusta el factor para el tamaño del círculo
        color=circle_color,
        fill=True,
        fill_color=circle_color,
        fill_opacity=0.7,
        popup=popup
    ).add_to(mapa_cdmx)

# 4. Mapa visual
cloudflared tuneel -- file:///C:/Users/geova/Downloads/Mapa_Web/mapa_albergues_cdmx.html.html--

print("Mapa de albergues generado exitosamente como mapa_albergues_cdmx.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import folium
from IPython.display import display
import seaborn as sns
import numpy as np
